# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("englander.csv")

# %%
# Get the game week number from the user
game_week_number = int(input("Enter the game week number (1-38): "))

# Select data for the specified game week
matchweek = data[data["Game Week"] == game_week_number]

matchweek[["date_GMT", "home_team_name", "home_team_goal_count","away_team_goal_count", "away_team_name",  "referee", "stadium_name"]]
# Out:
# Enter the game week number (1-38):  17
#                   date_GMT           home_team_name  home_team_goal_count  \
# 160  Dec 15 2018 - 12:30pm          Manchester City                     3
# 161   Dec 15 2018 - 3:00pm           Crystal Palace                     1
# 162   Dec 15 2018 - 3:00pm        Huddersfield Town                     0
# 163   Dec 15 2018 - 3:00pm        Tottenham Hotspur                     1
# 164   Dec 15 2018 - 3:00pm                  Watford                     3
# 165   Dec 15 2018 - 3:00pm  Wolverhampton Wanderers                     2
# 166   Dec 15 2018 - 5:30pm                   Fulham                     0
# 167   Dec 16 2018 - 1:30pm   Brighton & Hove Albion                     1
# 168   Dec 16 2018 - 1:30pm              Southampton                     3
# 169   Dec 16 2018 - 4:00pm                Liverpool                     3
#
#      away_team_goal_count     away_team_name          referee  \
# ...
